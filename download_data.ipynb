# %% [markdown]
# 1. Get access to 442final folder in colab file directory

# %%
# *Before this, make sure to a shortcut to MyDrive for /442final
from google.colab import drive
drive.mount('/content/drive')
# TODO: Fill in the Google Drive path where you uploaded the assignment
# Example: If you create a EECS442 folder and put all the files under HW5 folder, then 'EECS442/HW5'
GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = '442final'
# %load_ext autoreload
# %autoreload 2
import os
import sys
GOOGLE_DRIVE_PATH = os.path.join('drive', 'MyDrive', GOOGLE_DRIVE_PATH_AFTER_MYDRIVE)
sys.path.append(GOOGLE_DRIVE_PATH)
# %cd /content/drive/MyDrive/442final
# Out:
# Mounted at /content/drive
# /content/drive/.shortcut-targets-by-id/1YaORuZakoclaipt0yLo8K6RdzTi01RyM/442final

# %% [markdown]
# 2. Download dataset from kaggle
#
# First create a kaggle API token if you haven't got one: Go to `Kaggle` -> `Settings` -> `API` -> `create new token` -> `Download kaggle.json`
#
# The data is saved to `442final/train/geuguessr_filtered_data`. Give it ~20min to unzip.

# %%
! pip install -q kaggle
from google.colab import files
files.upload() # we'll upload kaggle.json
! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json
! kaggle datasets list
! kaggle datasets download -d annaglass1/geoguessr-55countries --path /content/drive/MyDrive/442final

# %%
! mkdir train
! unzip geoguessr-55countries.zip -d train
# Out:
#      <input type="file" id="files-6d815eec-89ba-4b3d-9947-2dd6c5f6b7c4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6d815eec-89ba-4b3d-9947-2dd6c5f6b7c4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
